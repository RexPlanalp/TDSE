# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
PES_7 = np.load("PES_7.npy")
PES_3 = np.load("PES_3.npy")

# %%
plt.semilogy(PES_7,color = "b",label = "N = 7",linestyle = "dashed")
plt.semilogy(PES_3,color = "k",label = "N = 3")
plt.xlim([0,250])
plt.legend()

np.sum(PES_3)
# Out:
# (0.0006073141719463811-1.1126521385616455e-14j)
