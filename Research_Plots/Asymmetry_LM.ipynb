# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
restricted = np.load("/users/becker/dopl4670/Research/TDSE/Research_Plots/A_slice_restricted.npy")
unrestricted = np.load("/users/becker/dopl4670/Research/TDSE/Research_Plots/A_slice_unrestricted.npy")

x = np.arange(0,2*np.pi,0.01)

plt.plot(x,restricted,label="Restricted")
plt.plot(x,unrestricted+0.05,label="Total+0.05")
plt.legend()
